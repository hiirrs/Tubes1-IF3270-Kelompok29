# %% [markdown]
# # Tugas Besar 1 - Kelompok 29
#
# Kelompok 29
# - Erdianti Wiga Putri Andini | 13522053
# - Shazya Audrea Taufik | 13522063
# - Zahira Dina Amalia | 13522085

# %% [markdown]
# ## Analisis Implementasi FFNN Terhadap Berbagai Kondisi
# 1. Depth dan width
# 2. Fungsi aktivasi
# 3. Variasi learning rate
# 4. Metode inisialisasi bobot
# 5. Perbandingan dengan implementasi MLP sklearn

# %%
# %pip install ipywidgets
import numpy as np
import matplotlib.pyplot as plt
import time
from sklearn.datasets import fetch_openml
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.neural_network import MLPClassifier
from tqdm.notebook import trange
import networkx as nx

from ffnn_imp import FeedForwardNN

# %% [markdown]
# ### Load and Prepare MNIST Dataset

# %%
# load dataset
mnist = fetch_openml('mnist_784', version=1, as_frame=False)
X, y = mnist.data, mnist.target.astype(int)

# scaling fitur
scaler = StandardScaler()
X = scaler.fit_transform(X)

# encode fitur
encoder = OneHotEncoder(sparse_output=False)
y_onehot = encoder.fit_transform(y.reshape(-1, 1))

# data splitting
X_train, X_test, y_train, y_test = train_test_split(X, y_onehot, test_size=0.2, random_state=42)

print(f"Training data shape: {X_train.shape}")
print(f"Training labels shape: {y_train.shape}")
# Out:
# Training data shape: (56000, 784)
# Training labels shape: (56000, 10)

# %% [markdown]
# ### Helper Functions for Analysis

# %%
def train_and_evaluate(model, X_train, y_train, X_test, y_test, batch_size=32, learning_rate=0.01, epochs=10, verbose=1):
    start_time = time.time()
    
    history = model.train(
        X_train, y_train,
        X_val=X_test, y_val=y_test,
        batch_size=batch_size,
        learning_rate=learning_rate,
        epochs=epochs,
        verbose=verbose
    )
    
    training_time = time.time() - start_time
    
    y_pred = model.predict(X_test)
    accuracy = np.mean(np.argmax(y_pred, axis=1) == np.argmax(y_test, axis=1))
    
    return {
        'model': model,
        'history': history,
        'accuracy': accuracy,
        'training_time': training_time,
        'y_pred': y_pred
    }

def plot_training_history(results, title, y_label='Loss'):
    plt.figure(figsize=(12, 6))
    
    for result in results:
        label = result['label']
        history = result['history']
        plt.plot(history['train_loss'], label=f'{label} (train)')
        plt.plot(history['val_loss'], label=f'{label} (val)', linestyle='--')
    
    plt.title(title)
    plt.xlabel('Epoch')
    plt.ylabel(y_label)
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.show()

def compare_accuracies(results, title):
    labels = [result['label'] for result in results]
    accuracies = [result['accuracy'] * 100 for result in results]
    
    plt.figure(figsize=(10, 6))
    plt.bar(labels, accuracies)
    plt.title(title)
    plt.xlabel('Model')
    plt.ylabel('Accuracy (%)')
    plt.ylim(0, 100)
    
    # Add accuracy values on top of bars
    for i, v in enumerate(accuracies):
        plt.text(i, v + 1, f"{v:.2f}%", ha='center')
    
    plt.grid(True, alpha=0.3, axis='y')
    plt.show()

def compare_weights_and_gradients(results, layer_idx=0):
    n_models = len(results)
    fig, axs = plt.subplots(n_models, 2, figsize=(12, 4 * n_models))
    
    for i, result in enumerate(results):
        model = result['model']
        label = result['label']
        
        # Plot weight distribution
        weights = model.layers[layer_idx].weights.flatten()
        axs[i, 0].hist(weights, bins=50, alpha=0.7)
        axs[i, 0].set_title(f"{label} - Layer {layer_idx+1} Weight Distribution")
        axs[i, 0].set_xlabel("Weight Value")
        axs[i, 0].set_ylabel("Frequency")
        axs[i, 0].grid(True, alpha=0.3)
        
        # Plot gradient distribution
        gradients = model.layers[layer_idx].weights_gradient.flatten()
        axs[i, 1].hist(gradients, bins=50, alpha=0.7, color='red')
        axs[i, 1].set_title(f"{label} - Layer {layer_idx+1} Gradient Distribution")
        axs[i, 1].set_xlabel("Gradient Value")
        axs[i, 1].set_ylabel("Frequency")
        axs[i, 1].grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.show()

# %%
# Ensure you've defined the `FeedForwardNN` class with the visualize_nn_graph method

# Example usage
common_params = {
    'batch_size': 32,
    'learning_rate': 0.01,
    'epochs': 10,
    'verbose': 1
}

# Create example models
model1 = FeedForwardNN(layer_dimensions=[784, 64, 10], activations=['relu', 'softmax'])
model2 = FeedForwardNN(layer_dimensions=[784, 128, 10], activations=['relu', 'softmax'])

# Train and evaluate both models
results1 = train_and_evaluate(model1, X_train, y_train, X_test, y_test, batch_size=common_params['batch_size'], learning_rate=common_params['learning_rate'], epochs=common_params['epochs'], verbose=common_params['verbose'])
results2 = train_and_evaluate(model2, X_train, y_train, X_test, y_test, batch_size=common_params['batch_size'], learning_rate=common_params['learning_rate'], epochs=common_params['epochs'], verbose=common_params['verbose'])

# Collect results for comparison
results = [
    {'label': 'Model 1', 'model': results1['model'], 'history': results1['history'], 'accuracy': results1['accuracy']},
    {'label': 'Model 2', 'model': results2['model'], 'history': results2['history'], 'accuracy': results2['accuracy']}
]

# Plot training history comparison
plot_training_history(results, title="Model Training History")

# Compare accuracies between models
compare_accuracies(results, title="Model Accuracy Comparison")

# Compare weight and gradient distributions for the first layer
compare_weights_and_gradients(results, layer_idx=0)

# Check the type of the model
print(f"Model Type: {type(results1['model'])}")

results1['model'].visualize_nn_graph(figsize=(12, 6))
# Out:
# Epoch 1/10 - Train Loss: 0.0309 - Val Loss: 0.0222
# Epoch 2/10 - Train Loss: 0.0186 - Val Loss: 0.0169
# Epoch 3/10 - Train Loss: 0.0158 - Val Loss: 0.0155
# Epoch 4/10 - Train Loss: 0.0139 - Val Loss: 0.0142
# Epoch 5/10 - Train Loss: 0.0123 - Val Loss: 0.0139
# Epoch 6/10 - Train Loss: 0.0115 - Val Loss: 0.0126
# Epoch 7/10 - Train Loss: 0.0106 - Val Loss: 0.0118
# Epoch 8/10 - Train Loss: 0.0099 - Val Loss: 0.0113
# Epoch 9/10 - Train Loss: 0.0096 - Val Loss: 0.0118
# Epoch 10/10 - Train Loss: 0.0088 - Val Loss: 0.0108
# Epoch 1/10 - Train Loss: 0.0287 - Val Loss: 0.0186
# Epoch 2/10 - Train Loss: 0.0167 - Val Loss: 0.0168
# Epoch 3/10 - Train Loss: 0.0141 - Val Loss: 0.0153
# Epoch 4/10 - Train Loss: 0.0126 - Val Loss: 0.0152
# Epoch 5/10 - Train Loss: 0.0109 - Val Loss: 0.0130
# Epoch 6/10 - Train Loss: 0.0100 - Val Loss: 0.0120
# Epoch 7/10 - Train Loss: 0.0091 - Val Loss: 0.0113
# Epoch 8/10 - Train Loss: 0.0085 - Val Loss: 0.0106
# Epoch 9/10 - Train Loss: 0.0078 - Val Loss: 0.0120
# Epoch 10/10 - Train Loss: 0.0072 - Val Loss: 0.0109
# Model Type: <class 'ffnn_imp.FeedForwardNN'>

# %% [markdown]
# ### 1. Analisis Pengaruh Depth dan Width

# %%
common_params = {
    'batch_size': 32,
    'learning_rate': 0.01,
    'epochs': 10,
    'verbose': 1
}

# 1. Width
print("\n=== Analisis Pengaruh Network Width ===")

width_results = []

# Depth tetap (3 layers: input -> hidden -> output), width divariasikan
width_configs = [
    {'dimensions': [784, 32, 10], 'label': 'Width 32'},
    {'dimensions': [784, 64, 10], 'label': 'Width 64'},
    {'dimensions': [784, 128, 10], 'label': 'Width 128'}
]

for config in width_configs:
    print(f"\nModel dengan {config['label']}")
    model = FeedForwardNN(
        layer_dimensions=config['dimensions'],
        activations=['relu', 'softmax'],
        loss='categorical_cross_entropy',
        weight_initializer='random_normal',
        weight_init_params={'mean': 0.0, 'variance': 0.01, 'seed': 42}
    )
    
    result = train_and_evaluate(
        model, X_train, y_train, X_test, y_test, batch_size=common_params['batch_size'], learning_rate=common_params['learning_rate'], epochs=common_params['epochs'], verbose=common_params['verbose']
    )
    
    result['label'] = config['label']
    width_results.append(result)
    print(f"Akurasi: {result['accuracy'] * 100:.2f}%, Waktu latih: {result['training_time']:.2f} detik")

# 2. Depth
print("\n=== Analisis Pengaruh Network Depth ===")

depth_results = []

# Width tetap (64 neurons per hidden layer), depth divariasikan
depth_configs = [
    {'dimensions': [784, 64, 10], 'activations': ['relu', 'softmax'], 'label': '1 Hidden Layer'},
    {'dimensions': [784, 64, 64, 10], 'activations': ['relu', 'relu', 'softmax'], 'label': '2 Hidden Layers'},
    {'dimensions': [784, 64, 64, 64, 10], 'activations': ['relu', 'relu', 'relu', 'softmax'], 'label': '3 Hidden Layers'}
]

for config in depth_configs:
    print(f"\nModel dengan {config['label']}")
    model = FeedForwardNN(
        layer_dimensions=config['dimensions'],
        activations=config['activations'],
        loss='categorical_cross_entropy',
        weight_initializer='random_normal',
        weight_init_params={'mean': 0.0, 'variance': 0.01, 'seed': 42}
    )
    
    result = train_and_evaluate(
        model, X_train, y_train, X_test, y_test, **common_params
    )
    
    result['label'] = config['label']
    depth_results.append(result)
    print(f"Akurasi: {result['accuracy'] * 100:.2f}%, Waktu latih: {result['training_time']:.2f} detik")
# Out:
# === Analisis Pengaruh Network Width ===
#
# Model dengan Width 32
# Epoch 1/10 - Train Loss: 3.2162 - Val Loss: 8.8006
# Epoch 2/10 - Train Loss: 6.2391 - Val Loss: 5.0768
# Epoch 3/10 - Train Loss: 6.0938 - Val Loss: 6.0938
# Epoch 4/10 - Train Loss: 5.7232 - Val Loss: 4.6808
# Epoch 5/10 - Train Loss: 6.0342 - Val Loss: 6.2444
# Epoch 6/10 - Train Loss: 6.4621 - Val Loss: 7.2408
# Epoch 7/10 - Train Loss: 6.1072 - Val Loss: 6.7474
# Epoch 8/10 - Train Loss: 6.4370 - Val Loss: 6.2019
# Epoch 9/10 - Train Loss: 6.0814 - Val Loss: 6.4213
# Epoch 10/10 - Train Loss: 6.1514 - Val Loss: 5.3826
# Akurasi: 84.38%, Waktu latih: 10.20 detik
#
# Model dengan Width 64
# Epoch 1/10 - Train Loss: 3.5844 - Val Loss: 5.9735
# Epoch 2/10 - Train Loss: 5.2683 - Val Loss: 4.8471
# Epoch 3/10 - Train Loss: 5.2814 - Val Loss: 4.1743
# Epoch 4/10 - Train Loss: 5.4143 - Val Loss: 8.9209
# Epoch 5/10 - Train Loss: 5.6107 - Val Loss: 5.0205
# Epoch 6/10 - Train Loss: 5.6940 - Val Loss: 4.8305
# Epoch 7/10 - Train Loss: 5.2292 - Val Loss: 5.3930
# Epoch 8/10 - Train Loss: 5.6385 - Val Loss: 5.2080
# Epoch 9/10 - Train Loss: 5.4429 - Val Loss: 5.1561
# Epoch 10/10 - Train Loss: 5.2154 - Val Loss: 4.7071
# Akurasi: 86.37%, Waktu latih: 12.40 detik
#
# Model dengan Width 128
# Epoch 1/10 - Train Loss: 4.3176 - Val Loss: 6.0835
# Epoch 2/10 - Train Loss: 5.2560 - Val Loss: 4.6233
# Epoch 3/10 - Train Loss: 5.2641 - Val Loss: 5.0624
# Epoch 4/10 - Train Loss: 5.1259 - Val Loss: 8.0574
# Epoch 5/10 - Train Loss: 4.9649 - Val Loss: 5.5262
# Epoch 6/10 - Train Loss: 5.0063 - Val Loss: 5.4941
# Epoch 7/10 - Train Loss: 4.8860 - Val Loss: 5.3066
# Epoch 8/10 - Train Loss: 5.3751 - Val Loss: 6.0739
# Epoch 9/10 - Train Loss: 5.1561 - Val Loss: 5.0254
# Epoch 10/10 - Train Loss: 5.1605 - Val Loss: 4.6307
# Akurasi: 86.59%, Waktu latih: 19.71 detik
#
# === Analisis Pengaruh Network Depth ===
#
# Model dengan 1 Hidden Layer
# Epoch 1/10 - Train Loss: 3.5844 - Val Loss: 5.9735
# Epoch 2/10 - Train Loss: 5.2683 - Val Loss: 4.8471
# Epoch 3/10 - Train Loss: 5.2814 - Val Loss: 4.1743
# Epoch 4/10 - Train Loss: 5.4143 - Val Loss: 8.9209
# Epoch 5/10 - Train Loss: 5.6107 - Val Loss: 5.0205
# Epoch 6/10 - Train Loss: 5.6940 - Val Loss: 4.8305
# Epoch 7/10 - Train Loss: 5.2292 - Val Loss: 5.3930
# Epoch 8/10 - Train Loss: 5.6385 - Val Loss: 5.2080
# Epoch 9/10 - Train Loss: 5.4429 - Val Loss: 5.1561
# Epoch 10/10 - Train Loss: 5.2154 - Val Loss: 4.7071
# Akurasi: 86.37%, Waktu latih: 11.96 detik
#
# Model dengan 2 Hidden Layers
# Epoch 1/10 - Train Loss: 0.4238 - Val Loss: 0.5054
# Epoch 2/10 - Train Loss: 0.4087 - Val Loss: 0.4099
# Epoch 3/10 - Train Loss: 0.6552 - Val Loss: 1.0255
# Epoch 4/10 - Train Loss: 0.9764 - Val Loss: 1.0096
# Epoch 5/10 - Train Loss: 1.5141 - Val Loss: 2.0635
# Epoch 6/10 - Train Loss: 2.2252 - Val Loss: 2.2136
# Epoch 7/10 - Train Loss: 2.2016 - Val Loss: 2.1906
# Epoch 8/10 - Train Loss: 2.2322 - Val Loss: 2.2211
# Epoch 9/10 - Train Loss: 2.2200 - Val Loss: 2.2243
# Epoch 10/10 - Train Loss: 2.2486 - Val Loss: 2.2819
# Akurasi: 10.87%, Waktu latih: 13.54 detik
#
# Model dengan 3 Hidden Layers
# Epoch 1/10 - Train Loss: 0.3918 - Val Loss: 0.2871
# Epoch 2/10 - Train Loss: 0.3815 - Val Loss: 0.7508
# Epoch 3/10 - Train Loss: 1.3068 - Val Loss: 2.3027
# Epoch 4/10 - Train Loss: 2.3075 - Val Loss: 2.2890
# Epoch 5/10 - Train Loss: 2.3494 - Val Loss: 2.3047
# Epoch 6/10 - Train Loss: 2.3037 - Val Loss: 2.3023
# Epoch 7/10 - Train Loss: 2.3036 - Val Loss: 2.3021
# Epoch 8/10 - Train Loss: 2.3037 - Val Loss: 2.3020
# Epoch 9/10 - Train Loss: 2.3035 - Val Loss: 2.3015
# Epoch 10/10 - Train Loss: 2.3035 - Val Loss: 2.3040
# Akurasi: 9.86%, Waktu latih: 15.22 detik

# %%
# visualisasi training loss untuk width yang berbeda-beda
plot_training_history(width_results, 'Training Loss vs Epoch (Variasi Width)')

# perbandingan akurasi antar perbedaan width
compare_accuracies(width_results, 'Perbandingan Akurasi (Variasi Width)')

# visualisasi training loss untuk depth yang berbeda-beda
plot_training_history(depth_results, 'Training Loss vs Epochs (Variasi Depth)')

# perbandingan akurasi antar perbedaan depth
compare_accuracies(depth_results, 'Perbandingan Akurasi (Variasi Depth)')

# %% [markdown]
# ### 2. Analisis Pengaruh Fungsi Aktivasi

# %%
print("\n=== Analisis Pengaruh Fungsi Aktivasi ===")

activation_results = []

activation_configs = [
    {'activation': 'linear', 'label': 'Linear'},
    {'activation': 'relu', 'label': 'ReLU'},
    {'activation': 'sigmoid', 'label': 'Sigmoid'},
    {'activation': 'tanh', 'label': 'Tanh'}
]

for config in activation_configs:
    print(f"\nModel dengan {config['label']} activation")
    model = FeedForwardNN(
        layer_dimensions=[784, 64, 10],
        activations=[config['activation'], 'softmax'],
        loss='categorical_cross_entropy',
        weight_initializer='random_normal',
        weight_init_params={'mean': 0.0, 'variance': 0.01, 'seed': 42}
    )
    
    result = train_and_evaluate(
        model, X_train, y_train, X_test, y_test, **common_params
    )
    
    result['label'] = config['label']
    activation_results.append(result)
    print(f"Akurasi: {result['accuracy'] * 100:.2f}%, Waktu latih: {result['training_time']:.2f} detik")
# Out:
# === Analisis Pengaruh Fungsi Aktivasi ===
#
# Model dengan Linear activation
# Epoch 1/10 - Train Loss: 8.7470 - Val Loss: 15.5597
# Epoch 2/10 - Train Loss: 9.7449 - Val Loss: 9.4562
# Epoch 3/10 - Train Loss: 9.5968 - Val Loss: 9.5500
# Epoch 4/10 - Train Loss: 9.8158 - Val Loss: 15.0540
# Epoch 5/10 - Train Loss: 9.7825 - Val Loss: 10.4529
# Epoch 6/10 - Train Loss: 9.7874 - Val Loss: 10.1100
# Epoch 7/10 - Train Loss: 9.5722 - Val Loss: 10.0113
# Epoch 8/10 - Train Loss: 9.6986 - Val Loss: 9.1922
# Epoch 9/10 - Train Loss: 9.6961 - Val Loss: 8.6396
# Epoch 10/10 - Train Loss: 9.6752 - Val Loss: 9.2342
# Akurasi: 73.26%, Waktu latih: 14.97 detik
#
# Model dengan ReLU activation
# Epoch 1/10 - Train Loss: 3.5844 - Val Loss: 5.9735
# Epoch 2/10 - Train Loss: 5.2683 - Val Loss: 4.8471
# Epoch 3/10 - Train Loss: 5.2814 - Val Loss: 4.1743
# Epoch 4/10 - Train Loss: 5.4143 - Val Loss: 8.9209
# Epoch 5/10 - Train Loss: 5.6107 - Val Loss: 5.0205
# Epoch 6/10 - Train Loss: 5.6940 - Val Loss: 4.8305
# Epoch 7/10 - Train Loss: 5.2292 - Val Loss: 5.3930
# Epoch 8/10 - Train Loss: 5.6385 - Val Loss: 5.2080
# Epoch 9/10 - Train Loss: 5.4429 - Val Loss: 5.1561
# Epoch 10/10 - Train Loss: 5.2154 - Val Loss: 4.7071
# Akurasi: 86.37%, Waktu latih: 12.63 detik
#
# Model dengan Sigmoid activation
# Epoch 1/10 - Train Loss: 0.3189 - Val Loss: 0.2172
# Epoch 2/10 - Train Loss: 0.1718 - Val Loss: 0.1788
# Epoch 3/10 - Train Loss: 0.1294 - Val Loss: 0.1676
# Epoch 4/10 - Train Loss: 0.1025 - Val Loss: 0.1564
# Epoch 5/10 - Train Loss: 0.0834 - Val Loss: 0.1535
# Epoch 6/10 - Train Loss: 0.0682 - Val Loss: 0.1485
# Epoch 7/10 - Train Loss: 0.0569 - Val Loss: 0.1509
# Epoch 8/10 - Train Loss: 0.0482 - Val Loss: 0.1484
# Epoch 9/10 - Train Loss: 0.0406 - Val Loss: 0.1506
# Epoch 10/10 - Train Loss: 0.0343 - Val Loss: 0.1508
# Akurasi: 95.86%, Waktu latih: 11.54 detik
#
# Model dengan Tanh activation
# Epoch 1/10 - Train Loss: 0.2850 - Val Loss: 0.2188
# Epoch 2/10 - Train Loss: 0.1661 - Val Loss: 0.1895
# Epoch 3/10 - Train Loss: 0.1304 - Val Loss: 0.1872
# Epoch 4/10 - Train Loss: 0.1109 - Val Loss: 0.1886
# Epoch 5/10 - Train Loss: 0.0933 - Val Loss: 0.1867
# Epoch 6/10 - Train Loss: 0.0790 - Val Loss: 0.1935
# Epoch 7/10 - Train Loss: 0.0699 - Val Loss: 0.1993
# Epoch 8/10 - Train Loss: 0.0624 - Val Loss: 0.2000
# Epoch 9/10 - Train Loss: 0.0583 - Val Loss: 0.2048
# Epoch 10/10 - Train Loss: 0.0553 - Val Loss: 0.2114
# Akurasi: 94.96%, Waktu latih: 11.85 detik

# %%
# training loss untuk berbagai fungsi aktivasi
plot_training_history(activation_results, 'Training Loss vs Epoch (Variasi Fungsi Aktivasi)')

# perbandingan akurasi antar perbedaan fungsi aktivasi
compare_accuracies(activation_results, 'Perbandingan Akurasi (Variasi Fungsi Aktivasi)')

# perbandingan weight dan gradien
compare_weights_and_gradients(activation_results, layer_idx=0)

# %% [markdown]
# ### 3. Analisis Pengaruh Learning Rate

# %%
print("\n=== Analisis Pengaruh Learning Rate ===")

lr_results = []

learning_rates = [0.001, 0.005, 0.01]

for lr in learning_rates:
    print(f"\nModel dengan learning rate {lr}")
    model = FeedForwardNN(
        layer_dimensions=[784, 64, 10],
        activations=['relu', 'softmax'],
        loss='categorical_cross_entropy',
        weight_initializer='random_normal',
        weight_init_params={'mean': 0.0, 'variance': 0.01, 'seed': 42}
    )
    
    params = common_params.copy()
    params['learning_rate'] = lr
    
    result = train_and_evaluate(
        model, X_train, y_train, X_test, y_test, **params
    )
    
    result['label'] = f'LR {lr}'
    lr_results.append(result)
    print(f"Akurasi: {result['accuracy'] * 100:.2f}%, Waktu latih: {result['training_time']:.2f} detik")
# Out:
# === Analisis Pengaruh Learning Rate ===
#
# Model dengan learning rate 0.001
# Epoch 1/10 - Train Loss: 0.4154 - Val Loss: 0.2710
# Epoch 2/10 - Train Loss: 0.2064 - Val Loss: 0.2087
# Epoch 3/10 - Train Loss: 0.1546 - Val Loss: 0.1992
# Epoch 4/10 - Train Loss: 0.1269 - Val Loss: 0.1760
# Epoch 5/10 - Train Loss: 0.1054 - Val Loss: 0.1674
# Epoch 6/10 - Train Loss: 0.0902 - Val Loss: 0.1669
# Epoch 7/10 - Train Loss: 0.0783 - Val Loss: 0.1633
# Epoch 8/10 - Train Loss: 0.0669 - Val Loss: 0.1610
# Epoch 9/10 - Train Loss: 0.0589 - Val Loss: 0.1563
# Epoch 10/10 - Train Loss: 0.0505 - Val Loss: 0.1592
# Akurasi: 96.17%, Waktu latih: 14.15 detik
#
# Model dengan learning rate 0.005
# Epoch 1/10 - Train Loss: 0.4218 - Val Loss: 0.3405
# Epoch 2/10 - Train Loss: 0.3787 - Val Loss: 0.3867
# Epoch 3/10 - Train Loss: 0.3546 - Val Loss: 0.3447
# Epoch 4/10 - Train Loss: 0.2596 - Val Loss: 0.4253
# Epoch 5/10 - Train Loss: 0.2257 - Val Loss: 0.4210
# Epoch 6/10 - Train Loss: 0.2266 - Val Loss: 0.3747
# Epoch 7/10 - Train Loss: 0.1758 - Val Loss: 0.4025
# Epoch 8/10 - Train Loss: 0.1559 - Val Loss: 0.3516
# Epoch 9/10 - Train Loss: 0.3630 - Val Loss: 0.7188
# Epoch 10/10 - Train Loss: 0.3916 - Val Loss: 0.8595
# Akurasi: 94.43%, Waktu latih: 13.23 detik
#
# Model dengan learning rate 0.01
# Epoch 1/10 - Train Loss: 3.5844 - Val Loss: 5.9735
# Epoch 2/10 - Train Loss: 5.2683 - Val Loss: 4.8471
# Epoch 3/10 - Train Loss: 5.2814 - Val Loss: 4.1743
# Epoch 4/10 - Train Loss: 5.4143 - Val Loss: 8.9209
# Epoch 5/10 - Train Loss: 5.6107 - Val Loss: 5.0205
# Epoch 6/10 - Train Loss: 5.6940 - Val Loss: 4.8305
# Epoch 7/10 - Train Loss: 5.2292 - Val Loss: 5.3930
# Epoch 8/10 - Train Loss: 5.6385 - Val Loss: 5.2080
# Epoch 9/10 - Train Loss: 5.4429 - Val Loss: 5.1561
# Epoch 10/10 - Train Loss: 5.2154 - Val Loss: 4.7071
# Akurasi: 86.37%, Waktu latih: 13.04 detik

# %%
# training loss untuk berbagai learning rate
plot_training_history(lr_results, 'Training Loss vs Epoch (Variasi Learning Rate)')

# perbandingan akurasi antar learning rate
compare_accuracies(lr_results, 'Perbadingan Akurasi (Variasi Learning Rate)')

# perbandingan weight dan gradien
compare_weights_and_gradients(lr_results, layer_idx=0)

# %% [markdown]
# ### 4. Analisis Pengaruh Metode Inisialisasi Bobot

# %%
print("\n=== Analisis Pengaruh Metode Inisialisasi Bobot ===")

init_results = []

init_configs = [
    {
        'initializer': 'zero',
        'params': None,
        'label': 'Zero Initialization'
    },
    {
        'initializer': 'random_uniform',
        'params': {'lower_bound': -0.05, 'upper_bound': 0.05, 'seed': 42},
        'label': 'Random Uniform'
    },
    {
        'initializer': 'random_normal',
        'params': {'mean': 0.0, 'variance': 0.01, 'seed': 42},
        'label': 'Random Normal'
    }
]

for config in init_configs:
    print(f"\nModel dengan {config['label']}")
    model = FeedForwardNN(
        layer_dimensions=[784, 64, 10],
        activations=['relu', 'softmax'],
        loss='categorical_cross_entropy',
        weight_initializer=config['initializer'],
        weight_init_params=config['params']
    )
    
    result = train_and_evaluate(
        model, X_train, y_train, X_test, y_test, **common_params
    )
    
    result['label'] = config['label']
    init_results.append(result)
    print(f"Akurasi: {result['accuracy'] * 100:.2f}%, Waktu latih: {result['training_time']:.2f} detik")
# Out:
# === Analisis Pengaruh Metode Inisialisasi Bobot ===
#
# Model dengan Zero Initialization
# Epoch 1/10 - Train Loss: 2.3038 - Val Loss: 2.3023
# Epoch 2/10 - Train Loss: 2.3039 - Val Loss: 2.3043
# Epoch 3/10 - Train Loss: 2.3036 - Val Loss: 2.3024
# Epoch 4/10 - Train Loss: 2.3035 - Val Loss: 2.3029
# Epoch 5/10 - Train Loss: 2.3037 - Val Loss: 2.3015
# Epoch 6/10 - Train Loss: 2.3035 - Val Loss: 2.3026
# Epoch 7/10 - Train Loss: 2.3037 - Val Loss: 2.3023
# Epoch 8/10 - Train Loss: 2.3037 - Val Loss: 2.3027
# Epoch 9/10 - Train Loss: 2.3037 - Val Loss: 2.3036
# Epoch 10/10 - Train Loss: 2.3036 - Val Loss: 2.3030
# Akurasi: 11.43%, Waktu latih: 14.52 detik
#
# Model dengan Random Uniform
# Epoch 1/10 - Train Loss: 1.6602 - Val Loss: 5.8546
# Epoch 2/10 - Train Loss: 4.9884 - Val Loss: 4.4117
# Epoch 3/10 - Train Loss: 5.6103 - Val Loss: 5.0723
# Epoch 4/10 - Train Loss: 5.5151 - Val Loss: 9.9472
# Epoch 5/10 - Train Loss: 5.8956 - Val Loss: 4.8034
# Epoch 6/10 - Train Loss: 5.6311 - Val Loss: 6.3132
# Epoch 7/10 - Train Loss: 5.3060 - Val Loss: 5.4300
# Epoch 8/10 - Train Loss: 5.3387 - Val Loss: 6.4958
# Epoch 9/10 - Train Loss: 5.2172 - Val Loss: 5.8099
# Epoch 10/10 - Train Loss: 5.1524 - Val Loss: 4.1521
# Akurasi: 87.98%, Waktu latih: 11.85 detik
#
# Model dengan Random Normal
# Epoch 1/10 - Train Loss: 3.5844 - Val Loss: 5.9735
# Epoch 2/10 - Train Loss: 5.2683 - Val Loss: 4.8471
# Epoch 3/10 - Train Loss: 5.2814 - Val Loss: 4.1743
# Epoch 4/10 - Train Loss: 5.4143 - Val Loss: 8.9209
# Epoch 5/10 - Train Loss: 5.6107 - Val Loss: 5.0205
# Epoch 6/10 - Train Loss: 5.6940 - Val Loss: 4.8305
# Epoch 7/10 - Train Loss: 5.2292 - Val Loss: 5.3930
# Epoch 8/10 - Train Loss: 5.6385 - Val Loss: 5.2080
# Epoch 9/10 - Train Loss: 5.4429 - Val Loss: 5.1561
# Epoch 10/10 - Train Loss: 5.2154 - Val Loss: 4.7071
# Akurasi: 86.37%, Waktu latih: 11.72 detik

# %%
# training loss untuk berbagai metode inisialisasi bobot
plot_training_history(init_results, 'Training Loss vs Epoch (Variasi Metode Inisialisasi)')

# perbandingan akurasi antar metode inisialisasi bobot
compare_accuracies(init_results, 'Perbandingan Akurasi (Variasi Metode Inisialisasi)')

# perbandingan bobot dan gradien
compare_weights_and_gradients(init_results, layer_idx=0)

# %% [markdown]
# ### 5. Comparison with sklearn's MLP

# %%
print("\n=== Perbandingan antara Hasil Implementasi dengan Library ===")

# latih ffnn hasil implementasi
print("\nImplementasi FFNN")
our_model = FeedForwardNN(
    layer_dimensions=[784, 64, 10],
    activations=['relu', 'softmax'],
    loss='categorical_cross_entropy',
    weight_initializer='random_normal',
    weight_init_params={'mean': 0.0, 'variance': 0.01, 'seed': 42}
)

our_result = train_and_evaluate(
    our_model, X_train, y_train, X_test, y_test,
    batch_size=32,
    learning_rate=0.001,
    epochs=10,
    verbose=1
)

# latih MLP dengan param mirip
print("\nMLP")
sklearn_mlp = MLPClassifier(
    hidden_layer_sizes=(64,),
    activation='relu',
    solver='sgd',
    alpha=0.0,
    batch_size=32,
    learning_rate_init=0.001,
    max_iter=10,
    random_state=42
)

start_time = time.time()
sklearn_mlp.fit(X_train, np.argmax(y_train, axis=1))
sklearn_time = time.time() - start_time

sklearn_preds = sklearn_mlp.predict(X_test)
sklearn_accuracy = np.mean(sklearn_preds == np.argmax(y_test, axis=1))

print(f"\nAkurasi Hasil Implementasi FFNN: {our_result['accuracy'] * 100:.2f}%, Waktu latih: {our_result['training_time']:.2f} detik")
print(f"Akurasi MLP sklearn: {sklearn_accuracy * 100:.2f}%, Waktu latih: {sklearn_time:.2f} detik")
# Out:
# === Perbandingan antara Hasil Implementasi dengan Library ===
#
# Implementasi FFNN
# Epoch 1/10 - Train Loss: 0.4154 - Val Loss: 0.2710
# Epoch 2/10 - Train Loss: 0.2064 - Val Loss: 0.2087
# Epoch 3/10 - Train Loss: 0.1546 - Val Loss: 0.1992
# Epoch 4/10 - Train Loss: 0.1269 - Val Loss: 0.1760
# Epoch 5/10 - Train Loss: 0.1054 - Val Loss: 0.1674
# Epoch 6/10 - Train Loss: 0.0902 - Val Loss: 0.1669
# Epoch 7/10 - Train Loss: 0.0783 - Val Loss: 0.1633
# Epoch 8/10 - Train Loss: 0.0669 - Val Loss: 0.1610
# Epoch 9/10 - Train Loss: 0.0589 - Val Loss: 0.1563
# Epoch 10/10 - Train Loss: 0.0505 - Val Loss: 0.1592
#
# MLP
#
# Akurasi Hasil Implementasi FFNN: 96.17%, Waktu latih: 15.39 detik
# Akurasi MLP sklearn: 95.88%, Waktu latih: 14.66 detik
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (10) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
comparison_results = [ {'label': 'FFNN Implementation', 'accuracy': our_result['accuracy']}, {'label': 'MLP sklearn', 'accuracy': sklearn_accuracy} ]
compare_accuracies(comparison_results, 'Perbandingan Akurasi (FFNN Implementasi vs MLP sklearn)')

# %%
our_model.save('ffnn_model.pkl')

# %%
loaded_model = FeedForwardNN.load('ffnn_model.pkl')

predictions = loaded_model.predict(X_test)

loaded_model.train(X_train, y_train, epochs=5)
# Out:
# Epoch 1/5 - Train Loss: 3.6528
# Epoch 2/5 - Train Loss: 5.3897
# Epoch 3/5 - Train Loss: 5.4927
# Epoch 4/5 - Train Loss: 5.5478
# Epoch 5/5 - Train Loss: 5.4473
# {'train_loss': [3.6528052167188942,
#   5.389734686667001,
#   5.492659930005329,
#   5.5477909584325875,
#   5.447258448568829],
#  'val_loss': []}
